# %% [markdown]
# # Task 1-1. Add StartDate for each quarter

# %%
import pandas as pd

# %%
df = pd.read_csv('./Data/Compustat Quarterly_snp1500_headquarters.csv', parse_dates = ['apdedateq','datadate'])

# %%
# 1280 companies
df['gvkey'].nunique()
# Out:
# 1280

# %%
df.shape
# Out:
# (35570, 12)

# %% [markdown]
# ## check NaN value

# %%
# NaN 데이터 수
df.isna().sum()
# Out:
# gvkey            0
# datadate         0
# year             0
# tic              0
# conm             0
# datacqtr        24
# apdedateq      292
# add1             0
# add2         35570
# add3         35570
# add4         35570
# addzip          28
# dtype: int64

# %%
# Number of companiy which has no QUANTILE information
df[df['datacqtr'].isna()].conm.nunique()
# Out:
# 7

# %%
# Number of company which has no ENDDATE information.
df[df['apdedateq'].isna()]['conm'].nunique()
# Out:
# 66

# %%
# drop the rows which has NaN values
df.dropna(subset = ['datacqtr', 'apdedateq'], inplace = True)

# %%
df
# Out:
#         gvkey   datadate  year  tic        conm datacqtr  apdedateq  \
# 0        1004 2015-02-28  2014  AIR    AAR CORP   2015Q1 2015-02-28
# 1        1004 2015-05-31  2014  AIR    AAR CORP   2015Q2 2015-05-31
# 2        1004 2015-08-31  2015  AIR    AAR CORP   2015Q3 2015-08-31
# 3        1004 2015-11-30  2015  AIR    AAR CORP   2015Q4 2015-11-30
# 4        1004 2016-02-29  2015  AIR    AAR CORP   2016Q1 2016-02-29
# ...       ...        ...   ...  ...         ...      ...        ...
# 35565  328795 2020-12-31  2020  ACA  ARCOSA INC   2020Q4 2020-12-31
# 35566  328795 2021-03-31  2021  ACA  ARCOSA INC   2021Q1 2021-03-31
# 35567  328795 2021-06-30  2021  ACA  ARCOSA INC   2021Q2 2021-06-30
# 35568  328795 2021-09-30  2021  ACA  ARCOSA INC   2021Q3 2021-09-30
# 35569  328795 2021-12-31  2021  ACA  ARCOSA INC   2021Q4 2021-12-31
#
#                                            add1  add2  add3  add4 addzip
# 0      One AAR Place, 1100 North Wood Dale Road   NaN   NaN   NaN  60191
# 1      One AAR Place, 1100 North Wood Dale Road   NaN   NaN   NaN  60191
# 2      One AAR Place, 1100 North Wood Dale Road   NaN   NaN   NaN  60191
# 3      One AAR Place, 1100 North Wood Dale Road   NaN   NaN   NaN  60191
# 4      One AAR Place, 1100 North Wood Dale Road   NaN   NaN   NaN  60191
# ...                                         ...   ...   ...   ...    ...
# 35565         500 North Akard Street, Suite 400   NaN   NaN   NaN  75201
# 35566         500 North Akard Street, Suite 400   NaN   NaN   NaN  75201
# 35567         500 North Akard Street, Suite 400   NaN   NaN   NaN  75201
# 35568         500 North Akard Street, Suite 400   NaN   NaN   NaN  75201
# 35569         500 North Akard Street, Suite 400   NaN   NaN   NaN  75201
#
# [35260 rows x 12 columns]

# %%
# Subtracting 90 days isn’t an exact approach to get the start of the quarter because quarters follow a structured calendar.
# So here I subtract 80 days first becuse 2 months usually never exceed 62 days and subtracting 80 days will ensure our date jump into the month of the starting month of the quarter we want to get.
# Then I get the first day of the month.

df['startdate'] = df['apdedateq'].apply(lambda x : (x - pd.Timedelta(days = 80)).replace(day=1))

# %%
df
# Out:
#         gvkey   datadate  year  tic        conm datacqtr  apdedateq  \
# 0        1004 2015-02-28  2014  AIR    AAR CORP   2015Q1 2015-02-28
# 1        1004 2015-05-31  2014  AIR    AAR CORP   2015Q2 2015-05-31
# 2        1004 2015-08-31  2015  AIR    AAR CORP   2015Q3 2015-08-31
# 3        1004 2015-11-30  2015  AIR    AAR CORP   2015Q4 2015-11-30
# 4        1004 2016-02-29  2015  AIR    AAR CORP   2016Q1 2016-02-29
# ...       ...        ...   ...  ...         ...      ...        ...
# 35565  328795 2020-12-31  2020  ACA  ARCOSA INC   2020Q4 2020-12-31
# 35566  328795 2021-03-31  2021  ACA  ARCOSA INC   2021Q1 2021-03-31
# 35567  328795 2021-06-30  2021  ACA  ARCOSA INC   2021Q2 2021-06-30
# 35568  328795 2021-09-30  2021  ACA  ARCOSA INC   2021Q3 2021-09-30
# 35569  328795 2021-12-31  2021  ACA  ARCOSA INC   2021Q4 2021-12-31
#
#                                            add1  add2  add3  add4 addzip  \
# 0      One AAR Place, 1100 North Wood Dale Road   NaN   NaN   NaN  60191
# 1      One AAR Place, 1100 North Wood Dale Road   NaN   NaN   NaN  60191
# 2      One AAR Place, 1100 North Wood Dale Road   NaN   NaN   NaN  60191
# 3      One AAR Place, 1100 North Wood Dale Road   NaN   NaN   NaN  60191
# 4      One AAR Place, 1100 North Wood Dale Road   NaN   NaN   NaN  60191
# ...                                         ...   ...   ...   ...    ...
# 35565         500 North Akard Street, Suite 400   NaN   NaN   NaN  75201
# 35566         500 North Akard Street, Suite 400   NaN   NaN   NaN  75201
# 35567         500 North Akard Street, Suite 400   NaN   NaN   NaN  75201
# 35568         500 North Akard Street, Suite 400   NaN   NaN   NaN  75201
# 35569         500 North Akard Street, Suite 400   NaN   NaN   NaN  75201
#
#        startdate
# 0     2014-12-01
# 1     2015-03-01
# 2     2015-06-01
# 3     2015-09-01
# 4     2015-12-01
# ...          ...
# 35565 2020-10-01
# 35566 2021-01-01
# 35567 2021-04-01
# 35568 2021-07-01
# 35569 2021-10-01
#
# [35260 rows x 13 columns]

# %%
# Get the current list of columns
cols = df.columns.tolist()

# %%
# Find the position of 'apdedateq'
apdedateq_index = cols.index('apdedateq')

# %%
# Reorder the columns to place 'startdate' before 'apdedateq'
new_cols = cols[:apdedateq_index] + ['startdate'] + cols[apdedateq_index:-1]

# %%
# Reorder the DataFrame with the new column order
df = df[new_cols]

# %%
df
# Out:
#         gvkey   datadate  year  tic        conm datacqtr  startdate  \
# 0        1004 2015-02-28  2014  AIR    AAR CORP   2015Q1 2014-12-01
# 1        1004 2015-05-31  2014  AIR    AAR CORP   2015Q2 2015-03-01
# 2        1004 2015-08-31  2015  AIR    AAR CORP   2015Q3 2015-06-01
# 3        1004 2015-11-30  2015  AIR    AAR CORP   2015Q4 2015-09-01
# 4        1004 2016-02-29  2015  AIR    AAR CORP   2016Q1 2015-12-01
# ...       ...        ...   ...  ...         ...      ...        ...
# 35565  328795 2020-12-31  2020  ACA  ARCOSA INC   2020Q4 2020-10-01
# 35566  328795 2021-03-31  2021  ACA  ARCOSA INC   2021Q1 2021-01-01
# 35567  328795 2021-06-30  2021  ACA  ARCOSA INC   2021Q2 2021-04-01
# 35568  328795 2021-09-30  2021  ACA  ARCOSA INC   2021Q3 2021-07-01
# 35569  328795 2021-12-31  2021  ACA  ARCOSA INC   2021Q4 2021-10-01
#
#        apdedateq                                      add1  add2  add3  add4  \
# 0     2015-02-28  One AAR Place, 1100 North Wood Dale Road   NaN   NaN   NaN
# 1     2015-05-31  One AAR Place, 1100 North Wood Dale Road   NaN   NaN   NaN
# 2     2015-08-31  One AAR Place, 1100 North Wood Dale Road   NaN   NaN   NaN
# 3     2015-11-30  One AAR Place, 1100 North Wood Dale Road   NaN   NaN   NaN
# 4     2016-02-29  One AAR Place, 1100 North Wood Dale Road   NaN   NaN   NaN
# ...          ...                                       ...   ...   ...   ...
# 35565 2020-12-31         500 North Akard Street, Suite 400   NaN   NaN   NaN
# 35566 2021-03-31         500 North Akard Street, Suite 400   NaN   NaN   NaN
# 35567 2021-06-30         500 North Akard Street, Suite 400   NaN   NaN   NaN
# 35568 2021-09-30         500 North Akard Street, Suite 400   NaN   NaN   NaN
# 35569 2021-12-31         500 North Akard Street, Suite 400   NaN   NaN   NaN
#
#       addzip
# 0      60191
# 1      60191
# 2      60191
# 3      60191
# 4      60191
# ...      ...
# 35565  75201
# 35566  75201
# 35567  75201
# 35568  75201
# 35569  75201
#
# [35260 rows x 13 columns]

# %%
df.to_csv('./Output/Task1-1.csv', index = False)
